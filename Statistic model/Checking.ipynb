# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
NIFTY.columns
# Out:
# Index(['Date', 'Close', 'Open', 'High', 'Low', 'Volume (in Billion)'], dtype='object')

# %%
NIFTY = pd.read_csv('D:/UFG/Data collection/NIFTY.csv')
NIFTY['Date']= pd.to_datetime(NIFTY['Date'], format='%Y-%m-%d')

# %%
NIFTY
# Out:
#            Date     Close      Open      High       Low  Volume (in Billion)
# 0    2000-01-03   1592.20   1482.15   1592.90   1482.15                25.36
# 1    2000-01-04   1638.70   1594.40   1641.95   1594.40                38.79
# 2    2000-01-05   1595.80   1634.55   1635.50   1555.05                62.15
# 3    2000-01-06   1617.60   1595.80   1639.00   1595.80                51.27
# 4    2000-01-07   1613.30   1616.60   1628.25   1597.20                54.32
# ...         ...       ...       ...       ...       ...                  ...
# 6066 2024-05-27  22932.45  23038.95  23110.80  22871.20               260.01
# 6067 2024-05-28  22888.15  22977.15  22998.55  22858.50               217.89
# 6068 2024-05-29  22704.70  22762.75  22825.50  22685.45               269.93
# 6069 2024-05-30  22488.65  22617.45  22705.75  22417.00               373.37
# 6070 2024-05-31  22530.70  22568.10  22653.75  22465.10               572.12
#
# [6071 rows x 6 columns]

# %%
# Filter data 
start_date = pd.to_datetime("2000-01-01", format='%Y-%m-%d')
end_date = pd.to_datetime("2000-06-01", format='%Y-%m-%d')
filtered_data = NIFTY[(NIFTY['Date'] >= start_date) & (NIFTY['Date'] < end_date)]

# %%
filtered_data
# Out:
#           Date    Close     Open     High      Low  Volume (in Billion)
# 0   2000-01-03  1592.20  1482.15  1592.90  1482.15                25.36
# 1   2000-01-04  1638.70  1594.40  1641.95  1594.40                38.79
# 2   2000-01-05  1595.80  1634.55  1635.50  1555.05                62.15
# 3   2000-01-06  1617.60  1595.80  1639.00  1595.80                51.27
# 4   2000-01-07  1613.30  1616.60  1628.25  1597.20                54.32
# ..         ...      ...      ...      ...      ...                  ...
# 97  2000-05-25  1247.65  1237.00  1269.80  1235.70                35.46
# 98  2000-05-26  1275.35  1247.10  1278.75  1232.85                33.05
# 99  2000-05-29  1311.05  1273.70  1317.75  1267.40                47.53
# 100 2000-05-30  1344.85  1310.80  1347.30  1304.95                35.58
# 101 2000-05-31  1380.45  1355.35  1410.75  1355.35                46.44
#
# [102 rows x 6 columns]

# %%
plt.figure(figsize=(14, 7))
plt.plot(filtered_data['Date'], filtered_data['Close'], label='NIFTY Close Price')
plt.xlabel('Date')
plt.ylabel('Price')
plt.xticks(rotation=45)
plt.legend()
plt.grid(True)
plt.show()

# %%
IBOV = pd.read_csv('D:/UFG/Data collection/IBOV.csv')
IBOV['Date']= pd.to_datetime(IBOV['Date'], format='%Y-%m-%d')

# %%
IBOV
# Out:
#            Date      Open      High       Low     Close  Volume (in Million)
# 0    2000-01-03   17098.0   17408.0   16719.0   16930.0               0.0000
# 1    2000-01-04   16908.0   16908.0   15851.0   15851.0               0.0000
# 2    2000-01-05   15871.0   16302.0   15350.0   16245.0               0.0000
# 3    2000-01-06   16237.0   16499.0   15977.0   16107.0               0.0000
# 4    2000-01-07   16125.0   16449.0   16125.0   16309.0               0.0000
# ...         ...       ...       ...       ...       ...                  ...
# 6039 2024-05-24  124731.0  125257.0  124259.0  124306.0               9.2115
# 6040 2024-05-27  124297.0  124535.0  124081.0  124496.0               4.3276
# 6041 2024-05-28  124498.0  125392.0  123537.0  123780.0               9.1798
# 6042 2024-05-29  123780.0  123780.0  122458.0  122707.0               8.2577
# 6043 2024-05-31  122704.0  122837.0  121929.0  122098.0              15.9186
#
# [6044 rows x 6 columns]
